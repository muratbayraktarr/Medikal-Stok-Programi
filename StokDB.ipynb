-- %% [markdown]
-- # [dbo].[PersonelTable]

-- %%
USE [StokDB]
GO

-- %%
/****** Object:  Table [dbo].[PersonelTable]    Script Date: 19.09.2022 14:42:11 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PersonelTable](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Personel İsmi] [nvarchar](50) NOT NULL,
	[Hazırlanan Ürün] [nvarchar](50) NOT NULL,
	[Adet] [smallint] NOT NULL,
	[Tarih] [datetime] NOT NULL,
	[Güncellenme Tarihi] [datetime] NOT NULL,
	[Açıklama] [nvarchar](300) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SiparisTable2]

-- %%
/****** Object:  Table [dbo].[SiparisTable2]    Script Date: 19.09.2022 14:42:11 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SiparisTable2](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Ürün İsmi] [nvarchar](100) NOT NULL,
	[Alıcı Firma] [nvarchar](200) NULL,
	[Adet] [int] NOT NULL,
	[Kalite] [nvarchar](50) NOT NULL,
	[Güncellenme Tarihi] [datetime] NULL,
	[Teslim Tarihi] [datetime] NOT NULL,
	[Açıklama] [nvarchar](300) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StokTable]

-- %%
/****** Object:  Table [dbo].[StokTable]    Script Date: 19.09.2022 14:42:11 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StokTable](
	[StokID] [int] IDENTITY(1,1) NOT NULL,
	[Ürün İsmi] [nvarchar](50) NOT NULL,
	[Adet] [int] NOT NULL,
	[Güncellenme Tarihi] [datetime] NOT NULL,
	[Stok Durumu] [nvarchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ÜrünTable4]

-- %%
/****** Object:  Table [dbo].[ÜrünTable4]    Script Date: 19.09.2022 14:42:11 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ÜrünTable4](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Ürün] [nvarchar](50) NOT NULL,
	[Güncellenme Tarihi] [datetime] NULL,
	[Resim] [image] NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO
